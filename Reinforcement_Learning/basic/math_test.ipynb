# %%
from numpy.random import choice

samples = choice(['R','G','B'],size=100,p=[0.2,0.5,0.3])
samples
# Out:
# array(['G', 'G', 'G', 'G', 'G', 'R', 'B', 'G', 'R', 'B', 'G', 'R', 'R',
#        'B', 'B', 'G', 'B', 'G', 'G', 'B', 'G', 'G', 'R', 'G', 'B', 'B',
#        'G', 'G', 'B', 'G', 'R', 'R', 'B', 'G', 'G', 'G', 'R', 'G', 'B',
#        'R', 'G', 'G', 'G', 'B', 'R', 'G', 'G', 'R', 'G', 'B', 'G', 'B',
#        'G', 'G', 'B', 'G', 'G', 'B', 'G', 'R', 'B', 'G', 'G', 'B', 'B',
#        'G', 'B', 'G', 'B', 'R', 'G', 'R', 'B', 'G', 'R', 'B', 'R', 'G',
#        'B', 'B', 'B', 'B', 'G', 'G', 'R', 'G', 'G', 'B', 'B', 'R', 'B',
#        'R', 'B', 'B', 'G', 'G', 'B', 'G', 'R', 'B'], dtype='<U1')
